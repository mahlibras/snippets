# %% [markdown]
# # Data Science Use Case: Front Running Detection using Classification And Regression Trees (CART)
# ## Written by Ricky Chang
# ### Based on Kx Product Insights: Front Running Alerts co-written by Ricky Chang at:
# https://kx.com/blog/kx-product-insights-front-running-alerts/
#
# Note: There is no executable Python code in this notebook. It contains only markdown for explanatory purposes.

# %% [markdown]
# I have found the representation of a CART decision tree using UML Activity conventions to be extremely useful for conveying complex algorithms to non-technical users.
#
# This is the legend for the symbols used in my CART representation:

# %% [markdown]
# ![CART-Legend-20190727.png](CART-Legend-20190727.png)

# %% [markdown]
# This CART represents the logical flowchart for detecting the _Front Running Variations_ described in my article.
#
# The decision nodes mostly deal with lookbacks to prior transactional events, since this CART is meant to be implemented in a real-time Complex Event Processing (CEP) engine, in which it is re-evaluated each time a relevant transaction is received.
#
# This CART is usually accompanied by descriptive pseudocode to describe the logical rules, terms & calculations used in greater detail.

# %% [markdown]
# ![FrontRunning-CARTFlowchart-20190727.png](FrontRunning-CARTFlowchart-20190727.png)

# %% [markdown]
# (C)2019 Ricky Chang
